# %%
a=5
b=5.2
c='A'
d="name"
e= True

# %%
print("integer:",a);
print("floal:",b);
print("charater",c);
print("string",d);
print("boolean",e);
# Out:
# integer: 5
# floal: 5.2
# charater A
# string name
# boolean True

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>

# %%
a=15
b=10
add=a+b
print("Add",add)
sub=a-b
print("Sub",sub)
mul=a+b
print("Mul",mul)
div=a/b
print("div",div)
mod=a%b
print("mod",mod)
flo_div=a//b
print("div",flo_div)
# Out:
# Add 25
# Sub 5
# Mul 25
# div 1.5
# mod 5
# div 1

# %%
c=True
d=False
print(c and d)
print(c or d)
print (not a)
# Out:
# False
# True
# False

# %%
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# True
# False
# True
# False
# False
# True
